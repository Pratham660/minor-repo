# %% [markdown]
# # Bitcoin Price Prediction Using Machine Learning & Deep Learning Methods

# %% [markdown]
# ## Preprocessing Of Dataset

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
df = pd.read_csv("dataset.csv")
df['date'] = pd.to_datetime(df['Timestamp'],unit='s').dt.date
df['Volume_(BTC)'].fillna(value=0, inplace=True)
df['Volume_(Currency)'].fillna(value=0, inplace=True)
df['Weighted_Price'].fillna(value=0, inplace=True)

# next we need to fix the OHLC (open high low close) data which is a continuous timeseries so
# lets fill forwards those values...
df['Open'].fillna(method='ffill', inplace=True)
df['High'].fillna(method='ffill', inplace=True)
df['Low'].fillna(method='ffill', inplace=True)
df['Close'].fillna(method='ffill', inplace=True)
print(df.head)

group = df.groupby('date')
real_price = group['Weighted_Price'].mean()
prediction_days = 30
train= real_price[len(real_price)-prediction_days:]
test= real_price[:len(real_price)-prediction_days]
training_set = train.values
training_set = np.reshape(training_set, (len(training_set), 1))
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
training_set = ms.fit_transform(training_set)
X_train = training_set[0:len(training_set)-1]
y_train = training_set[1:len(training_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))
print(df.head)
#print(df.head)
# Out:
# <bound method NDFrame.head of           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980      4.39      4.39      4.39      4.39      0.000000
# 2        1325318040      4.39      4.39      4.39      4.39      0.000000
# 3        1325318100      4.39      4.39      4.39      4.39      0.000000
# 4        1325318160      4.39      4.39      4.39      4.39      0.000000
# ...             ...       ...       ...       ...       ...           ...
# 4572252  1600041360  10324.35  10325.89  10324.35  10325.89      0.081143
# 4572253  1600041420  10331.41  10331.97  10326.68  10331.97      0.572817
# 4572254  1600041480  10327.20  10331.47  10321.33  10331.47      2.489909
# 4572255  1600041540  10330.02  10334.78  10328.64  10334.78      4.572660
# 4572256  1600041600  10338.82  10338.82  10332.37  10332.37      1.292006
#
#          Volume_(Currency)  Weighted_Price        date
# 0                 2.000000        4.390000  2011-12-31
# 1                 0.000000        0.000000  2011-12-31
# 2                 0.000000        0.000000  2011-12-31
# 3                 0.000000        0.000000  2011-12-31
# 4                 0.000000        0.000000  2011-12-31
# ...                    ...             ...         ...
# 4572252         837.754188    10324.419779  2020-09-13
# 4572253        5918.028741    10331.444396  2020-09-13
# 4572254       25711.238323    10326.175283  2020-09-13
# 4572255       47253.747619    10333.972651  2020-09-13
# 4572256       13349.565122    10332.429402  2020-09-14
#
# [4572257 rows x 9 columns]>
# <bound method NDFrame.head of           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980      4.39      4.39      4.39      4.39      0.000000
# 2        1325318040      4.39      4.39      4.39      4.39      0.000000
# 3        1325318100      4.39      4.39      4.39      4.39      0.000000
# 4        1325318160      4.39      4.39      4.39      4.39      0.000000
# ...             ...       ...       ...       ...       ...           ...
# 4572252  1600041360  10324.35  10325.89  10324.35  10325.89      0.081143
# 4572253  1600041420  10331.41  10331.97  10326.68  10331.97      0.572817
# 4572254  1600041480  10327.20  10331.47  10321.33  10331.47      2.489909
# 4572255  1600041540  10330.02  10334.78  10328.64  10334.78      4.572660
# 4572256  1600041600  10338.82  10338.82  10332.37  10332.37      1.292006
#
#          Volume_(Currency)  Weighted_Price        date
# 0                 2.000000        4.390000  2011-12-31
# 1                 0.000000        0.000000  2011-12-31
# 2                 0.000000        0.000000  2011-12-31
# 3                 0.000000        0.000000  2011-12-31
# 4                 0.000000        0.000000  2011-12-31
# ...                    ...             ...         ...
# 4572252         837.754188    10324.419779  2020-09-13
# 4572253        5918.028741    10331.444396  2020-09-13
# 4572254       25711.238323    10326.175283  2020-09-13
# 4572255       47253.747619    10333.972651  2020-09-13
# 4572256       13349.565122    10332.429402  2020-09-14
#
# [4572257 rows x 9 columns]>

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, mask=matrix)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,13))
plt.suptitle('Lag Plots', fontsize=22)
#warnings.filterwarnings('ignore')

#lag in minutes
plt.subplot(3,3,1)
pd.plotting.lag_plot(df['Weighted_Price'], lag=1) #minute lag
plt.title('1-Minute Lag')

plt.subplot(3,3,2)
pd.plotting.lag_plot(df['Weighted_Price'], lag=60) #hourley lag
plt.title('1-Hour Lag')

plt.subplot(3,3,3)
pd.plotting.lag_plot(df['Weighted_Price'], lag=1440) #Daily lag
plt.title('Daily Lag')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import seaborn as sns
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
warnings.filterwarnings('ignore')
plt.style.use('seaborn-poster')
#df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')
#df.index = df.Timestamp
df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')
df.index = df.Timestamp
df = df.resample('D').mean()
df_month = df.resample('M').mean()
df_year = df.resample('A-DEC').mean()
df_Q = df.resample('Q-DEC').mean()


fig = plt.figure(figsize=[15, 7])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(df.Weighted_Price, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Weighted_Price, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Weighted_Price, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Weighted_Price, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Some Statistics !!

# %%
plt.figure(figsize=[15,7])
sm.tsa.seasonal_decompose(df_month.Weighted_Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.746581

# %%
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Weighted_Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
# Out:
# Dickey–Fuller test: p=0.746581

# %%
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.186309

# %%
#seasonl differencing
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.186309

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000008

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 19  (1, 0, 0, 1)  268.939082
# 7   (0, 1, 0, 1)  269.236607
# 21  (1, 0, 1, 1)  269.689214
# 9   (0, 1, 1, 1)  269.905340
# 23  (1, 0, 2, 1)  270.034472
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                   Weighted_Price_box   No. Observations:                  106
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -131.470
# Date:                              Mon, 14 Dec 2020   AIC                            268.939
# Time:                                      11:47:10   BIC                            276.537
# Sample:                                  12-31-2011   HQIC                           272.007
#                                        - 09-30-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3687      0.092      4.015      0.000       0.189       0.549
# ma.S.L12      -0.9959      7.808     -0.128      0.898     -16.299      14.307
# sigma2         0.7497      5.811      0.129      0.897     -10.639      12.138
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 6.34
# Prob(Q):                              0.87   Prob(JB):                         0.04
# Heteroskedasticity (H):               1.00   Skew:                             0.48
# Prob(H) (two-sided):                  1.00   Kurtosis:                         3.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %% [markdown]
# ## Arima Model

# %%
df_month2 = df_month[['Weighted_Price']]
date_list = [datetime(2020, 9,14), datetime(2020, 11, 3), datetime(2020, 12, 30), 
             datetime(2021, 1, 31), datetime(2021, 2 ,2),datetime(2021, 3,2), datetime(2021, 4,3),
             datetime(2021,5,8)
             ]

future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])
df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=500),lmbda)
plt.figure(figsize=(15,7))
df_month2.Weighted_Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Weighted_Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()

# %% [markdown]
# ## Building LSTM

# %%
bit_data=pd.read_csv("dataset.csv")
bit_data["date"]=pd.to_datetime(bit_data["Timestamp"],unit="s").dt.date
group=bit_data.groupby("date")
data=group["Close"].mean()

# %%
data.shape
# Out:
# (3178,)

# %%
data.isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
# date
# 2011-12-31    4.482500
# 2012-01-01    4.806667
# 2012-01-02    5.000000
# 2012-01-03    5.252500
# 2012-01-04    5.223333
# Name: Close, dtype: float64

# %%
data.tail()
# Out:
# date
# 2020-09-10    10338.760864
# 2020-09-11    10302.451926
# 2020-09-12    10372.583252
# 2020-09-13    10392.960134
# 2020-09-14    10332.370000
# Name: Close, dtype: float64

# %%
close_train=data.iloc[:len(data)-50]
close_test=data.iloc[len(close_train):]

# %%
#feature scalling (set values between 0-1)
close_train=np.array(close_train)
close_train=close_train.reshape(close_train.shape[0],1)
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
close_scaled=scaler.fit_transform(close_train)

# %%
timestep=50
x_train=[]
y_train=[]

for i in range(timestep,close_scaled.shape[0]):
    x_train.append(close_scaled[i-timestep:i,0])
    y_train.append(close_scaled[i,0])

x_train,y_train=np.array(x_train),np.array(y_train)
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1) #reshaped for LSTM
print("x_train shape= ",x_train.shape)
print("y_train shape= ",y_train.shape)
# Out:
# x_train shape=  (3078, 50, 1)
# y_train shape=  (3078,)

# %%
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout,Flatten

model=Sequential()

model.add(LSTM(10,input_shape=(None,1),activation="relu"))

model.add(Dense(1))

model.compile(loss="mean_squared_error",optimizer="adam",metrics=['accuracy'])

model.fit(x_train,y_train,epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 97/97 [==============================] - 5s 47ms/step - loss: 0.0321 - accuracy: 3.2489e-04
# Epoch 2/100
# 97/97 [==============================] - 5s 47ms/step - loss: 0.0011 - accuracy: 6.4977e-04
# Epoch 3/100
# 97/97 [==============================] - 4s 37ms/step - loss: 5.6996e-04 - accuracy: 6.4977e-04
# Epoch 4/100
# 97/97 [==============================] - 4s 45ms/step - loss: 5.3961e-04 - accuracy: 6.4977e-04
# Epoch 5/100
# 97/97 [==============================] - 5s 54ms/step - loss: 5.0856e-04 - accuracy: 6.4977e-04
# Epoch 6/100
# 97/97 [==============================] - 4s 37ms/step - loss: 4.7175e-04 - accuracy: 6.4977e-04
# Epoch 7/100
# 97/97 [==============================] - 4s 39ms/step - loss: 4.3504e-04 - accuracy: 6.4977e-04
# Epoch 8/100
# 97/97 [==============================] - 4s 42ms/step - loss: 3.9742e-04 - accuracy: 6.4977e-04
# Epoch 9/100
# 97/97 [==============================] - 4s 39ms/step - loss: 3.7406e-04 - accuracy: 6.4977e-04
# Epoch 10/100
# 97/97 [==============================] - 4s 37ms/step - loss: 3.4199e-04 - accuracy: 6.4977e-04
# Epoch 11/100
# 97/97 [==============================] - 4s 38ms/step - loss: 3.2602e-04 - accuracy: 6.4977e-04
# Epoch 12/100
# 97/97 [==============================] - 4s 44ms/step - loss: 3.0408e-04 - accuracy: 6.4977e-04
# Epoch 13/100
# 97/97 [==============================] - 5s 48ms/step - loss: 2.9040e-04 - accuracy: 6.4977e-04
# Epoch 14/100
# 97/97 [==============================] - 3s 35ms/step - loss: 2.7835e-04 - accuracy: 6.4977e-04
# Epoch 15/100
# 97/97 [==============================] - 3s 36ms/step - loss: 2.6592e-04 - accuracy: 6.4977e-04
# Epoch 16/100
# 97/97 [==============================] - 4s 38ms/step - loss: 2.5722e-04 - accuracy: 6.4977e-04
# Epoch 17/100
# 97/97 [==============================] - 5s 51ms/step - loss: 2.5070e-04 - accuracy: 6.4977e-04
# Epoch 18/100
# 97/97 [==============================] - 3s 36ms/step - loss: 2.3924e-04 - accuracy: 6.4977e-04
# Epoch 19/100
# 97/97 [==============================] - 4s 40ms/step - loss: 2.3004e-04 - accuracy: 6.4977e-04 0s - loss:
# Epoch 20/100
# 97/97 [==============================] - 6s 58ms/step - loss: 2.2429e-04 - accuracy: 6.4977e-04
# Epoch 21/100
# 97/97 [==============================] - 4s 46ms/step - loss: 2.1314e-04 - accuracy: 6.4977e-04
# Epoch 22/100
# 97/97 [==============================] - 3s 35ms/step - loss: 2.0572e-04 - accuracy: 6.4977e-04
# Epoch 23/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.9294e-04 - accuracy: 6.4977e-04
# Epoch 24/100
# 97/97 [==============================] - 4s 42ms/step - loss: 1.8535e-04 - accuracy: 6.4977e-04
# Epoch 25/100
# 97/97 [==============================] - 5s 48ms/step - loss: 1.8646e-04 - accuracy: 6.4977e-04
# Epoch 26/100
# 97/97 [==============================] - 3s 35ms/step - loss: 1.9080e-04 - accuracy: 6.4977e-04
# Epoch 27/100
# 97/97 [==============================] - 4s 43ms/step - loss: 1.7318e-04 - accuracy: 6.4977e-04
# Epoch 28/100
# 97/97 [==============================] - 4s 38ms/step - loss: 1.7633e-04 - accuracy: 6.4977e-04
# Epoch 29/100
# 97/97 [==============================] - 4s 46ms/step - loss: 1.6758e-04 - accuracy: 6.4977e-04
# Epoch 30/100
# 97/97 [==============================] - 3s 32ms/step - loss: 1.6004e-04 - accuracy: 6.4977e-04
# Epoch 31/100
# 97/97 [==============================] - 5s 48ms/step - loss: 1.6099e-04 - accuracy: 6.4977e-04 0s - loss: 1.6525e-04 - accura - ETA: 0s - loss: 1.6338e-04 - accuracy: 7.1023 - ETA: 0s - loss: 1.6171e-04 - accu
# Epoch 32/100
# 97/97 [==============================] - 5s 52ms/step - loss: 1.6139e-04 - accuracy: 6.4977e-04 0s - loss: 1
# Epoch 33/100
# 97/97 [==============================] - 4s 39ms/step - loss: 1.5353e-04 - accuracy: 6.4977e-04
# Epoch 34/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.6405e-04 - accuracy: 6.4977e-04
# Epoch 35/100
# 97/97 [==============================] - 5s 53ms/step - loss: 1.5652e-04 - accuracy: 6.4977e-04
# Epoch 36/100
# 97/97 [==============================] - 5s 55ms/step - loss: 1.5227e-04 - accuracy: 6.4977e-04
# Epoch 37/100
# 97/97 [==============================] - 3s 34ms/step - loss: 1.5365e-04 - accuracy: 6.4977e-04
# Epoch 38/100
# 97/97 [==============================] - 5s 49ms/step - loss: 1.5280e-04 - accuracy: 6.4977e-04 0s - loss: 1.4949e-04 - accuracy: 4.0064e- - ETA: 0s - l
# Epoch 39/100
# 97/97 [==============================] - 6s 62ms/step - loss: 1.4457e-04 - accuracy: 6.4977e-04
# Epoch 40/100
# 97/97 [==============================] - 4s 44ms/step - loss: 1.4420e-04 - accuracy: 6.4977e-04
# Epoch 41/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.4416e-04 - accuracy: 6.4977e-04
# Epoch 42/100
# 97/97 [==============================] - 4s 46ms/step - loss: 1.5881e-04 - accuracy: 6.4977e-04
# Epoch 43/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.3557e-04 - accuracy: 6.4977e-04
# Epoch 44/100
# 97/97 [==============================] - 4s 40ms/step - loss: 1.4318e-04 - accuracy: 6.4977e-04
# Epoch 45/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.4727e-04 - accuracy: 6.4977e-04
# Epoch 46/100
# 97/97 [==============================] - 4s 39ms/step - loss: 1.4132e-04 - accuracy: 6.4977e-04
# Epoch 47/100
# 97/97 [==============================] - 5s 49ms/step - loss: 1.3317e-04 - accuracy: 6.4977e-04
# Epoch 48/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.3913e-04 - accuracy: 6.4977e-04
# Epoch 49/100
# 97/97 [==============================] - 3s 35ms/step - loss: 1.4407e-04 - accuracy: 6.4977e-04
# Epoch 50/100
# 97/97 [==============================] - 5s 48ms/step - loss: 1.4746e-04 - accuracy: 6.4977e-04
# Epoch 51/100
# 97/97 [==============================] - 5s 49ms/step - loss: 1.3613e-04 - accuracy: 6.4977e-04
# Epoch 52/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.4558e-04 - accuracy: 6.4977e-04
# Epoch 53/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.3534e-04 - accuracy: 6.4977e-04
# Epoch 54/100
# 97/97 [==============================] - 5s 53ms/step - loss: 1.3848e-04 - accuracy: 6.4977e-04
# Epoch 55/100
# 97/97 [==============================] - 5s 54ms/step - loss: 1.2682e-04 - accuracy: 6.4977e-04- loss:
# Epoch 56/100
# 97/97 [==============================] - 3s 34ms/step - loss: 1.3154e-04 - accuracy: 6.4977e-04
# Epoch 57/100
# 97/97 [==============================] - 3s 29ms/step - loss: 1.2966e-04 - accuracy: 6.4977e-04
# Epoch 58/100
# 97/97 [==============================] - 4s 44ms/step - loss: 1.2739e-04 - accuracy: 6.4977e-04
# Epoch 59/100
# 97/97 [==============================] - 4s 44ms/step - loss: 1.2279e-04 - accuracy: 6.4977e-04
# Epoch 60/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.3067e-04 - accuracy: 6.4977e-04
# Epoch 61/100
# 97/97 [==============================] - 3s 35ms/step - loss: 1.2536e-04 - accuracy: 6.4977e-04
# Epoch 62/100
# 97/97 [==============================] - 4s 38ms/step - loss: 1.2237e-04 - accuracy: 6.4977e-04
# Epoch 63/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.2822e-04 - accuracy: 6.4977e-04
# Epoch 64/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.2760e-04 - accuracy: 6.4977e-04
# Epoch 65/100
# 97/97 [==============================] - 3s 36ms/step - loss: 1.2778e-04 - accuracy: 6.4977e-04
# Epoch 66/100
# 97/97 [==============================] - 4s 39ms/step - loss: 1.2223e-04 - accuracy: 6.4977e-04
# Epoch 67/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.2783e-04 - accuracy: 6.4977e-04
# Epoch 68/100
# 97/97 [==============================] - 4s 45ms/step - loss: 1.3621e-04 - accuracy: 6.4977e-04
# Epoch 69/100
# 97/97 [==============================] - 3s 33ms/step - loss: 1.2175e-04 - accuracy: 6.4977e-04
# Epoch 70/100
# 97/97 [==============================] - 5s 51ms/step - loss: 1.2159e-04 - accuracy: 6.4977e-04
# Epoch 71/100
# 97/97 [==============================] - 4s 45ms/step - loss: 1.1830e-04 - accuracy: 6.4977e-04
# Epoch 72/100
# 97/97 [==============================] - 4s 38ms/step - loss: 1.1617e-04 - accuracy: 6.4977e-04
# Epoch 73/100
# 97/97 [==============================] - 3s 33ms/step - loss: 1.1539e-04 - accuracy: 6.4977e-04
# Epoch 74/100
# 97/97 [==============================] - 5s 52ms/step - loss: 1.1639e-04 - accuracy: 6.4977e-04
# Epoch 75/100
# 97/97 [==============================] - 4s 46ms/step - loss: 1.1585e-04 - accuracy: 6.4977e-04
# Epoch 76/100
# 97/97 [==============================] - 4s 43ms/step - loss: 1.2380e-04 - accuracy: 6.4977e-04
# Epoch 77/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.2327e-04 - accuracy: 6.4977e-04
# Epoch 78/100
# 97/97 [==============================] - 4s 45ms/step - loss: 1.1725e-04 - accuracy: 6.4977e-04
# Epoch 79/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.1608e-04 - accuracy: 6.4977e-04
# Epoch 80/100
# 97/97 [==============================] - 4s 41ms/step - loss: 1.1004e-04 - accuracy: 6.4977e-04
# Epoch 81/100
# 97/97 [==============================] - 3s 34ms/step - loss: 1.2057e-04 - accuracy: 6.4977e-04
# Epoch 82/100
# 97/97 [==============================] - 4s 46ms/step - loss: 1.3288e-04 - accuracy: 6.4977e-04
# Epoch 83/100
# 97/97 [==============================] - 4s 40ms/step - loss: 1.1550e-04 - accuracy: 6.4977e-04
# Epoch 84/100
# 97/97 [==============================] - 4s 42ms/step - loss: 1.1919e-04 - accuracy: 6.4977e-04
# Epoch 85/100
# 97/97 [==============================] - 4s 39ms/step - loss: 1.2733e-04 - accuracy: 6.4977e-04 0s - loss: 1.2647e-04 - accuracy:  - ETA: 0s - loss: 1.2751e-04 - accuracy: 6.5104e-
# Epoch 86/100
# 97/97 [==============================] - 4s 43ms/step - loss: 1.2590e-04 - accuracy: 6.4977e-04 0s - loss: 1.2614e-04 - accuracy: 6.5104
# Epoch 87/100
# 97/97 [==============================] - 4s 44ms/step - loss: 1.1490e-04 - accuracy: 6.4977e-04
# Epoch 88/100
# 97/97 [==============================] - 4s 37ms/step - loss: 1.1864e-04 - accuracy: 6.4977e-04
# Epoch 89/100
# 97/97 [==============================] - 3s 33ms/step - loss: 1.0953e-04 - accuracy: 6.4977e-04 0s - loss: 1.0915e-04
# Epoch 90/100
# 97/97 [==============================] - 4s 41ms/step - loss: 1.2129e-04 - accuracy: 6.4977e-04
# Epoch 91/100
# 97/97 [==============================] - 7s 67ms/step - loss: 1.2192e-04 - accuracy: 6.4977e-04
# Epoch 92/100
# 97/97 [==============================] - 3s 35ms/step - loss: 1.1821e-04 - accuracy: 6.4977e-04
# Epoch 93/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.1839e-04 - accuracy: 6.4977e-04
# Epoch 94/100
# 97/97 [==============================] - 5s 56ms/step - loss: 1.1532e-04 - accuracy: 6.4977e-04
# Epoch 95/100
# 97/97 [==============================] - 4s 46ms/step - loss: 1.1240e-04 - accuracy: 6.4977e-04
# Epoch 96/100
# 97/97 [==============================] - 3s 34ms/step - loss: 1.0736e-04 - accuracy: 6.4977e-04
# Epoch 97/100
# 97/97 [==============================] - 5s 47ms/step - loss: 1.1290e-04 - accuracy: 6.4977e-04
# Epoch 98/100
# 97/97 [==============================] - 4s 45ms/step - loss: 1.1147e-04 - accuracy: 6.4977e-04
# Epoch 99/100
# 97/97 [==============================] - 4s 36ms/step - loss: 1.2591e-04 - accuracy: 6.4977e-04
# Epoch 100/100
# 97/97 [==============================] - 3s 34ms/step - loss: 1.1154e-04 - accuracy: 6.4977e-04

# %%
inputs=data[len(data)-len(close_test)-timestep:]
inputs=inputs.values.reshape(-1,1)
inputs=scaler.transform(inputs)

# %%
x_test=[]
for i in range(timestep,inputs.shape[0]):
    x_test.append(inputs[i-timestep:i,0])
x_test=np.array(x_test)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
predicted_data=model.predict(x_test)
predicted_data=scaler.inverse_transform(predicted_data)

# %%
data_test=np.array(close_test)
data_test=data_test.reshape(len(data_test),1)

# %%
plt.figure(figsize=(12,6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(data_test,color="g",label="Real Price")
plt.plot(predicted_data,color="b",label="Predicted Price")
plt.legend()
plt.xlabel("Time(50 days)")
plt.ylabel("Price (Close Values)")
plt.grid(True)
plt.show()

# %%
cvscores = []
scores = model.evaluate(x_test, data_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# accuracy: 0.00%
# 0.00% (+/- 0.00%)

# %% [markdown]
# ## Stacked LSTM Model

# %%
import tensorflow as tf
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout,Flatten



model=Sequential()

model.add(LSTM(10,input_shape=(None,1),return_sequences=True))
model.add(LSTM(10, return_sequences=True))
#model.add(LSTM(10))
model.add(Dense(1))

model.compile(loss="mean_squared_error",optimizer="adam")

model.fit(x_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0155
# Epoch 2/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0071
# Epoch 3/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0061
# Epoch 4/100
# 97/97 [==============================] - 7s 73ms/step - loss: 0.0056
# Epoch 5/100
# 97/97 [==============================] - 8s 85ms/step - loss: 0.0052
# Epoch 6/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0049
# Epoch 7/100
# 97/97 [==============================] - 9s 95ms/step - loss: 0.0047
# Epoch 8/100
# 97/97 [==============================] - 8s 83ms/step - loss: 0.0045
# Epoch 9/100
# 97/97 [==============================] - 8s 83ms/step - loss: 0.0043
# Epoch 10/100
# 97/97 [==============================] - 8s 79ms/step - loss: 0.0042:
# Epoch 11/100
# 97/97 [==============================] - 8s 82ms/step - loss: 0.0041:
# Epoch 12/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0040
# Epoch 13/100
# 97/97 [==============================] - 9s 88ms/step - loss: 0.0039
# Epoch 14/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0038
# Epoch 15/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0037: 0s - lo
# Epoch 16/100
# 97/97 [==============================] - 8s 81ms/step - loss: 0.0037
# Epoch 17/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0036: 1s
# Epoch 18/100
# 97/97 [==============================] - 8s 80ms/step - loss: 0.0036
# Epoch 19/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0034
# Epoch 20/100
# 97/97 [==============================] - 8s 82ms/step - loss: 0.0034
# Epoch 21/100
# 97/97 [==============================] - 9s 90ms/step - loss: 0.0033
# Epoch 22/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0033
# Epoch 23/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0034: 0s - loss: 0
# Epoch 24/100
# 97/97 [==============================] - 8s 80ms/step - loss: 0.0033
# Epoch 25/100
# 97/97 [==============================] - 8s 83ms/step - loss: 0.0032
# Epoch 26/100
# 97/97 [==============================] - 7s 73ms/step - loss: 0.0032
# Epoch 27/100
# 97/97 [==============================] - 9s 88ms/step - loss: 0.0032
# Epoch 28/100
# 97/97 [==============================] - 8s 79ms/step - loss: 0.0032
# Epoch 29/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0031
# Epoch 30/100
# 97/97 [==============================] - 8s 80ms/step - loss: 0.0031
# Epoch 31/100
# 97/97 [==============================] - 9s 90ms/step - loss: 0.0031
# Epoch 32/100
# 97/97 [==============================] - 8s 79ms/step - loss: 0.0031
# Epoch 33/100
# 97/97 [==============================] - 8s 83ms/step - loss: 0.0031
# Epoch 34/100
# 97/97 [==============================] - 8s 79ms/step - loss: 0.0031: 0s - loss: 0. - ETA: 0s - loss: 0.00
# Epoch 35/100
# 97/97 [==============================] - 8s 84ms/step - loss: 0.0031
# Epoch 36/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0030
# Epoch 37/100
# 97/97 [==============================] - 8s 86ms/step - loss: 0.0030
# Epoch 38/100
# 97/97 [==============================] - 7s 70ms/step - loss: 0.0030
# Epoch 39/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0030: 0s - loss: 0 - ETA: 0s - loss: 0.00
# Epoch 40/100
# 97/97 [==============================] - 7s 76ms/step - loss: 0.0030
# Epoch 41/100
# 97/97 [==============================] - 9s 90ms/step - loss: 0.0030
# Epoch 42/100
# 97/97 [==============================] - 7s 75ms/step - loss: 0.0030: 1s - - ETA: 1s - loss: - ETA: 0s - los
# Epoch 43/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0030
# Epoch 44/100
# 97/97 [==============================] - 6s 65ms/step - loss: 0.0029
# Epoch 45/100
# 97/97 [==============================] - 8s 81ms/step - loss: 0.0029
# Epoch 46/100
# 97/97 [==============================] - 7s 74ms/step - loss: 0.0029
# Epoch 47/100
# 97/97 [==============================] - 8s 86ms/step - loss: 0.0029: 1s -
# Epoch 48/100
# 97/97 [==============================] - 7s 71ms/step - loss: 0.0029
# Epoch 49/100
# 97/97 [==============================] - 9s 88ms/step - loss: 0.0029
# Epoch 50/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0030
# Epoch 51/100
# 97/97 [==============================] - 9s 89ms/step - loss: 0.0029
# Epoch 52/100
# 97/97 [==============================] - 7s 74ms/step - loss: 0.0029: 0s - loss: 0.0
# Epoch 53/100
# 97/97 [==============================] - 9s 92ms/step - loss: 0.0029: 0s - loss: 0.
# Epoch 54/100
# 97/97 [==============================] - 8s 79ms/step - loss: 0.0029: 1s  - ETA: 0s - loss: 0.
# Epoch 55/100
# 97/97 [==============================] - 8s 86ms/step - loss: 0.0029: 0s - loss
# Epoch 56/100
# 97/97 [==============================] - 6s 67ms/step - loss: 0.0029
# Epoch 57/100
# 97/97 [==============================] - 8s 84ms/step - loss: 0.0029
# Epoch 58/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0029
# Epoch 59/100
# 97/97 [==============================] - 8s 85ms/step - loss: 0.0029
# Epoch 60/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0029
# Epoch 61/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0029
# Epoch 62/100
# 97/97 [==============================] - 7s 70ms/step - loss: 0.0029
# Epoch 63/100
# 97/97 [==============================] - 9s 91ms/step - loss: 0.0029
# Epoch 64/100
# 97/97 [==============================] - 7s 69ms/step - loss: 0.0029
# Epoch 65/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0029: 0s - loss: 0.00
# Epoch 66/100
# 97/97 [==============================] - 7s 70ms/step - loss: 0.0029
# Epoch 67/100
# 97/97 [==============================] - 7s 76ms/step - loss: 0.0029
# Epoch 68/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0029
# Epoch 69/100
# 97/97 [==============================] - 9s 91ms/step - loss: 0.0029
# Epoch 70/100
# 97/97 [==============================] - 8s 81ms/step - loss: 0.0029
# Epoch 71/100
# 97/97 [==============================] - 10s 102ms/step - loss: 0.0028
# Epoch 72/100
# 97/97 [==============================] - 6s 66ms/step - loss: 0.0029
# Epoch 73/100
# 97/97 [==============================] - 7s 75ms/step - loss: 0.0029
# Epoch 74/100
# 97/97 [==============================] - 7s 76ms/step - loss: 0.0029
# Epoch 75/100
# 97/97 [==============================] - 9s 90ms/step - loss: 0.0029
# Epoch 76/100
# 97/97 [==============================] - 7s 69ms/step - loss: 0.0028
# Epoch 77/100
# 97/97 [==============================] - 8s 86ms/step - loss: 0.0029
# Epoch 78/100
# 97/97 [==============================] - 8s 84ms/step - loss: 0.0030
# Epoch 79/100
# 97/97 [==============================] - 8s 82ms/step - loss: 0.0029
# Epoch 80/100
# 97/97 [==============================] - 10s 107ms/step - loss: 0.00291s -
# Epoch 81/100
# 97/97 [==============================] - 11s 111ms/step - loss: 0.0028
# Epoch 82/100
# 97/97 [==============================] - 8s 82ms/step - loss: 0.0028
# Epoch 83/100
# 97/97 [==============================] - 7s 67ms/step - loss: 0.0028
# Epoch 84/100
# 97/97 [==============================] - 7s 71ms/step - loss: 0.0028
# Epoch 85/100
# 97/97 [==============================] - 9s 94ms/step - loss: 0.0028
# Epoch 86/100
# 97/97 [==============================] - 8s 80ms/step - loss: 0.0028
# Epoch 87/100
# 97/97 [==============================] - 7s 76ms/step - loss: 0.0028
# Epoch 88/100
# 97/97 [==============================] - 7s 68ms/step - loss: 0.0028
# Epoch 89/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0028
# Epoch 90/100
# 97/97 [==============================] - 6s 67ms/step - loss: 0.0028
# Epoch 91/100
# 97/97 [==============================] - 7s 71ms/step - loss: 0.0028
# Epoch 92/100
# 97/97 [==============================] - 7s 77ms/step - loss: 0.0027
# Epoch 93/100
# 97/97 [==============================] - 8s 77ms/step - loss: 0.0027
# Epoch 94/100
# 97/97 [==============================] - 7s 72ms/step - loss: 0.0027
# Epoch 95/100
# 97/97 [==============================] - 8s 78ms/step - loss: 0.0028
# Epoch 96/100
# 97/97 [==============================] - 8s 87ms/step - loss: 0.0028
# Epoch 97/100
# 97/97 [==============================] - 8s 85ms/step - loss: 0.0027
# Epoch 98/100
# 97/97 [==============================] - 7s 74ms/step - loss: 0.0028
# Epoch 99/100
# 97/97 [==============================] - 7s 73ms/step - loss: 0.0027
# Epoch 100/100
# 97/97 [==============================] - 7s 76ms/step - loss: 0.0027

# %%
inputs=data[len(data)-len(close_test)-timestep:]
inputs=inputs.values.reshape(-1,1)
inputs=scaler.transform(inputs)

x_test=[]
for i in range(timestep,inputs.shape[0]):
    x_test.append(inputs[i-timestep:i,0])
x_test=np.array(x_test)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
predicted_data=model.predict(x_test)
print(predicted_data.shape)

predicted_data=scaler.inverse_transform(predicted_data)

data_test=np.array(close_test)
data_test=data_test.reshape(len(data_test),1)
# Out:
# (50, 50, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-787e5edf2ebe> in <module>
#       2 print(predicted_data.shape)
#       3
# ----> 4 predicted_data=scaler.inverse_transform(predicted_data)
#       5
#       6 data_test=np.array(close_test)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     427         check_is_fitted(self)
#     428
# --> 429         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
#     430                         force_all_finite="allow-nan")
#     431
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     638             array = array.astype(np.float64)
#     639         if not allow_nd and array.ndim >= 3:
# --> 640             raise ValueError("Found array with dim %d. %s expected <= 2."
#     641                              % (array.ndim, estimator_name))
#     642
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
plt.figure(figsize=(12,6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(data_test,color="g",label="Real Price")
plt.plot(predicted_data,color="b",label="Predicted Price")
plt.legend()
plt.xlabel("Time(50 days)")
plt.ylabel("Price (Close Values)")
plt.grid(True)
plt.show()

# %%
#prediction using svm
data=pd.read_csv("CBBTCUSD.csv")

# %%
data.head(7)

# %%
data.tail()

# %%
data.drop(['DATE'], 1, inplace=True)

# %%
data.head()

# %%
prediction_days = 30
data['Prediction'] = data[['CBBTCUSD']].shift(-prediction_days)

# %%
data.head(7)

# %%
data.tail(7)

# %%
X = np.array(data.drop(['Prediction'],1))
X= X[:len(data)-prediction_days]
print(X)

# %%
y = np.array(data['Prediction'])  
y = y[:-prediction_days] 
print(y)

# %%
# Split the data into 80% training and 20% testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Set prediction_days_array equal to the last 30 rows of the original data set from the price column
prediction_days_array = np.array(data.drop(['Prediction'],1))[-prediction_days:]
print(prediction_days_array)

# %%
from sklearn.svm import SVR
# Create and train the Support Vector Machine 
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.00001)#Create the model
svr_rbf.fit(x_train, y_train) #Train the model

# %%
# Testing Model: Score returns the accuracy of the prediction. 
# The best possible score is 1.0
svr_rbf_confidence = svr_rbf.score(x_test, y_test)
print("svr_rbf accuracy: ", svr_rbf_confidence)

# %%
# Print the predicted value
svm_prediction = svr_rbf.predict(x_test)
print(svm_prediction)

print()

#Print the actual values
print(y_test)

# %%
# Print the model predictions for the next 'n=30' days
svm_prediction = svr_rbf.predict(prediction_days_array)
print(svm_prediction)

# %%
#Print the actual price for the next 'n' days, n=prediction_days=30 
data.tail(prediction_days)

# %%
plt.plot(data)
